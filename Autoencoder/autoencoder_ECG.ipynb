# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharva2116/DL/blob/main/Autoencoder/autoencoder_ECG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ecg.csv')

# %%
df
# Out:
#       -0.11252183  -2.8272038  -3.7738969  -4.3497511  -4.376041  -3.4749863  \
# 0       -1.100878   -3.996840   -4.285843   -4.506579  -4.022377   -3.234368
# 1       -0.567088   -2.593450   -3.874230   -4.584095  -4.187449   -3.151462
# 2        0.490473   -1.914407   -3.616364   -4.318823  -4.268016   -3.881110
# 3        0.800232   -0.874252   -2.384761   -3.973292  -4.338224   -3.802422
# 4       -1.507674   -3.574550   -4.478011   -4.408275  -3.321242   -2.105171
# ...           ...         ...         ...         ...        ...         ...
# 4992     0.608558   -0.335651   -0.990948   -1.784153  -2.626145   -2.957065
# 4993    -2.060402   -2.860116   -3.405074   -3.748719  -3.513561   -3.006545
# 4994    -1.122969   -2.252925   -2.867628   -3.358605  -3.167849   -2.638360
# 4995    -0.547705   -1.889545   -2.839779   -3.457912  -3.929149   -3.966026
# 4996    -1.351779   -2.209006   -2.520225   -3.061475  -3.065141   -3.030739
#
# ...

# %%
df.columns=range(df.shape[1])

# %%
df.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -1.100878 -3.996840 -4.285843 -4.506579 -4.022377 -3.234368 -1.566126
# 1 -0.567088 -2.593450 -3.874230 -4.584095 -4.187449 -3.151462 -1.742940
# 2  0.490473 -1.914407 -3.616364 -4.318823 -4.268016 -3.881110 -2.993280
# 3  0.800232 -0.874252 -2.384761 -3.973292 -4.338224 -3.802422 -2.534510
# 4 -1.507674 -3.574550 -4.478011 -4.408275 -3.321242 -2.105171 -1.481048
#
#         7         8         9    ...       131       132       133       134  \
# 0 -0.992258 -0.754680  0.042321  ...  0.538356  0.656881  0.787490  0.724046
# 1 -1.490659 -1.183580 -0.394229  ...  0.886073  0.531452  0.311377 -0.021919
# 2 -1.671131 -1.333884 -0.965629  ...  0.350816  0.499111  0.600345  0.842069
# 3 -1.783423 -1.594450 -0.753199  ...  1.148884  0.958434  1.059025  1.371682
# 4 -1.301362 -0.498240 -0.286928  ...  1.089068  0.983369  1.014124  0.952629
#
#         135       136       137       138       139  140
# ...

# %%
x=df.drop([140],axis=1)
y=df[140]

# %%
scaler=StandardScaler()
x=scaler.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
encoder=keras.Sequential([
    layers.Input(shape=(x_train.shape[1],)), # Use x_train.shape[1] to get the number of features
    layers.Dense(64,activation='relu'),
    layers.Dense(32,activation='relu'),
    layers.Dense(16,activation='relu'),
])

# %%
decoder=keras.Sequential([
    layers.Input(shape=(16,)),
    layers.Dense(32,activation='relu'),
    layers.Dense(64,activation='relu'),
    layers.Dense(x_train.shape[1],activation='linear')
])

# %%
autoencoder=keras.Sequential([
    encoder,
    decoder
])

# %%
autoencoder.compile(optimizer='adam',loss='mean_squared_error')

# %%
history=autoencoder.fit(x_train,x_train,epochs=10,batch_size=32,shuffle=True,validation_data=(x_test,x_test))
# Out:
# Epoch 1/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.7430 - val_loss: 0.3362
# Epoch 2/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2772 - val_loss: 0.2497
# Epoch 3/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1954 - val_loss: 0.2123
# Epoch 4/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1737 - val_loss: 0.1878
# Epoch 5/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1477 - val_loss: 0.1709
# Epoch 6/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1309 - val_loss: 0.1634
# Epoch 7/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1272 - val_loss: 0.1442
# Epoch 8/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1275 - val_loss: 0.1299
# Epoch 9/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1160 - val_loss: 0.1328
# Epoch 10/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1052 - val_loss: 0.1229

# %%
predict=autoencoder.predict(x_test)
mse=np.mean((x_test-predict)**2 ,axis=1)

threshold=np.percentile(mse,95)
y_test_pred=np.where(mse>threshold,1,0)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
y_test_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_test_pred)
accuracy
# Out:
# 0.4136

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('MSLE Loss')
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
anomalies = mse > threshold

# %%
# Print the number of anomalies detected
print(f'Number of anomalies detected: {np.sum(anomalies)}')
# Out:
# Number of anomalies detected: 63
